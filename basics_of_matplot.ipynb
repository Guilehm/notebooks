# %%
import random
import numpy as np
from matplotlib import style
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Bar Chart with alpha

# %%
data_1 = list(range(10))
data_2 = [random.randint(1, 10) for x in range(10)]

# %%
data_3 = list(range(10))
data_4 = [random.randint(1, 10) for x in range(10)]

# %%
plt.bar(data_1, data_2, label='Bars1')
plt.bar(data_3, data_4, label='Bars2', alpha=0.8)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph')
# Out:
# Text(0.5, 1.0, 'Interesting Graph')

# %% [markdown]
# # Stackplot

# %%
constant = list(range(10))
data_1 = [random.randint(1, 20) for x in range(10)]
data_2 = [random.randint(1, 20) for x in range(10)]
data_3 = [random.randint(1, 20) for x in range(10)]
data_4 = [random.randint(1, 20) for x in range(10)]

# %% [markdown]
# ### Create legends first, then Stackplot Graph

# %%
plt.plot([], [], color='r', label='data_1', linewidth=5)
plt.plot([], [], color='b', label='data_2', linewidth=5)
plt.plot([], [], color='c', label='data_3', linewidth=5)
plt.plot([], [], color='g', label='data_4', linewidth=5)

plt.stackplot(constant, data_1, data_2, data_3, data_4, colors=list('rbcg'))
plt.legend()
plt.title('Stackplot Graph')
# Out:
# Text(0.5, 1.0, 'Stackplot Graph')

# %% [markdown]
# # Pie Charts

# %%
slices = [9, 3, 3, 14]
activities = ['sleeping', 'eating', 'working', 'playing']

# %%
plt.pie(
    slices, 
    labels=activities, 
    startangle=45, 
    shadow=True, 
    explode=(0, 0.2, 0, 0),
    autopct='%1.1f%%',
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe1827576d8>,
#   <matplotlib.patches.Wedge at 0x7fe1827610b8>,
#   <matplotlib.patches.Wedge at 0x7fe182761a58>,
#   <matplotlib.patches.Wedge at 0x7fe18276b438>],
#  [Text(-0.20728981441336028, 1.0802920590472165, 'sleeping'),
#   Text(-1.2957115393602523, 0.10550642998739695, 'eating'),
#   Text(-0.9268403082335556, -0.592424715076547, 'working'),
#   Text(0.8187868638874041, -0.73456658753678, 'playing')],
#  [Text(-0.1130671714981965, 0.5892502140257544, '31.0%'),
#   Text(-0.7973609472986167, 0.06492703383839812, '10.3%'),
#   Text(-0.5055492590364847, -0.32314075367811657, '10.3%'),
#   Text(0.44661101666585673, -0.40067268411097084, '48.3%')])

# %% [markdown]
# # 3D Bar Chart

# %%
x3 = list(range(1, 11))
y3 = [random.randint(1, 8) for x in range(10)]
z3 = [random.randint(1, 8) for x in range(10)]

# %%
dx = np.ones(10)
dy = np.ones(10)
dz = list(range(1, 11))

# %%
style.use('fivethirtyeight')
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.bar3d(x3, y3, z3, dx, dy, dz)

# %%
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')

# %%
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')

_x = np.arange(4)
_y = np.arange(5)
_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()

top = x + y
bottom = np.zeros_like(top)
width = depth = 1

ax1.bar3d(x, y, bottom, width, depth, top, shade=True)
ax1.set_title('Shaded')

ax2.bar3d(x, y, bottom, width, depth, top, shade=False)
ax2.set_title('Not Shaded')
# Out:
# Text(0.5, 0.92, 'Not Shaded')
