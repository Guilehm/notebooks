# %%
import random
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('source/airplanes_ocurrences/oco.csv')

# %% [markdown]
# # Head of data frame

# %%
df.head()
# Out:
#    codigo_ocorrencia ocorrencia_classificacao  \
# 0    201305055424986                 ACIDENTE
# 1    201311259977425          INCIDENTE GRAVE
# 2    201605160250139          INCIDENTE GRAVE
# 3    201805021421302                INCIDENTE
# 4    200808073991179                 ACIDENTE
#
#                                      ocorrencia_tipo  \
# 0                              FALHA DO MOTOR EM VOO
# 1                                     POUSO SEM TREM
# 2  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO
# 3                                          AERÓDROMO
# 4                          PERDA DE CONTROLE NO SOLO
#
#                            ocorrencia_tipo_categoria ocorrencia_tipo_icao  \
# 0                FALHA OU MAU FUNCIONAMENTO DO MOTOR               SCF-PP
# 1                        CONTATO ANORMAL COM A PISTA                  ARC
# 2  COLISÃO COM OBSTÁCULO DURANTE A DECOLAGEM E POUSO                 CTOL
# ...

# %% [markdown]
# # Convert from int64 to str and slice

# %%
df['codigo_ocorrencia'] = df['codigo_ocorrencia'].apply(str)

# %% [markdown]
# # Split and store values converting to integers

# %%
df['ano_ocorrencia'] = df['codigo_ocorrencia'].str[:4].astype(int)
df['mes_ocorrencia'] = df['codigo_ocorrencia'].str[4:6].astype(int)
df['dia_ocorrencia'] = df['codigo_ocorrencia'].str[6:8].astype(int)

# %% [markdown]
# #  Find occurences in 2018

# %%
df.loc[df['ano_ocorrencia'] == 2018]
# Out:
#      codigo_ocorrencia ocorrencia_classificacao  \
# 3      201805021421302                INCIDENTE
# 128    201803011722167          INCIDENTE GRAVE
# 133    201804101509299          INCIDENTE GRAVE
# 206    201803091904444                 ACIDENTE
# 250    201803281316034                INCIDENTE
# 325    201802281920364                 ACIDENTE
# 355    201804251556497                 ACIDENTE
# 433    201801161138317                 ACIDENTE
# 480    201804031740555                INCIDENTE
# 490    201804171653537                 ACIDENTE
# 503    201803021416074                INCIDENTE
# 547    201801041135187          INCIDENTE GRAVE
# 548    201802281755435                 ACIDENTE
# 549    201802281417066                 ACIDENTE
# 557    201805041436502          INCIDENTE GRAVE
# 644    201804201518248                 ACIDENTE
# 678    201803161630146                 ACIDENTE
# 683    201805181318558                 ACIDENTE
# ...

# %% [markdown]
# # Count ocurrences by year

# %%
df.ano_ocorrencia.value_counts()
# Out:
# 2012    623
# 2013    620
# 2014    538
# 2011    527
# 2010    490
# 2015    449
# 2009    444
# 2008    431
# 2017    413
# 2016    379
# 2018    166
# Name: ano_ocorrencia, dtype: int64
