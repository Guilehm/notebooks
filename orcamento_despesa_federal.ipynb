# %%
import pandas as pd

# %%
df = pd.read_csv('source/orcamento_despesa_federal/2018_orcamento_despesa.csv', encoding='ISO-8859-1', sep=';')

# %%
df.head()
# Out:
#    EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR          NOME ÓRGÃO SUPERIOR  \
# 0       2018                   3000  TRIBUNAL DE CONTAS DA UNIAO
# 1       2018                  12000              JUSTICA FEDERAL
# 2       2018                  20000     PRESIDENCIA DA REPUBLICA
# 3       2018                  20000     PRESIDENCIA DA REPUBLICA
# 4       2018                  20000     PRESIDENCIA DA REPUBLICA
#
#    CÓDIGO ÓRGÃO SUBORDINADO  \
# 0                      3000
# 1                     12000
# 2                     22201
# 3                     22201
# 4                     22201
#
#                               NOME ÓRGÃO SUBORDINADO  \
# 0  TRIBUNAL DE CONTAS DA UNIAO - UNIDADES COM VÍN...
# 1      JUSTICA FEDERAL - UNIDADES COM VÍNCULO DIRETO
# 2      INSTIT. NAC. DE COLONIZACAO E REFORMA AGRARIA
# 3      INSTIT. NAC. DE COLONIZACAO E REFORMA AGRARIA
# 4      INSTIT. NAC. DE COLONIZACAO E REFORMA AGRARIA
#
# ...

# %% [markdown]
# # Ministérios
# por quantidade de orçamento

# %%
df['NOME ÓRGÃO SUPERIOR'].value_counts()
# Out:
# MINISTERIO DA EDUCACAO                           10169
# MINISTERIO DA DEFESA                              1986
# MINISTERIO DA SAUDE                               1475
# MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES     1212
# MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL         1144
# MINISTERIO DA INTEGRACAO NACIONAL                  999
# MINISTERIO DA FAZENDA                              930
# PRESIDENCIA DA REPUBLICA                           881
# MINISTERIO DA JUSTICA                              825
# MINISTERIO DO MEIO AMBIENTE                        786
# MINISTERIO DE MINAS E ENERGIA                      726
# MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO       712
# MINISTERIO DA CULTURA                              695
# MINISTERIO DO DESENVOLVIMENTO SOCIAL               514
# MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO       496
# MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS      340
# MINISTERIO DAS CIDADES                             324
# ...

# %% [markdown]
# # Categorias Econômicas

# %%
df['NOME CATEGORIA ECONÔMICA'].value_counts()
# Out:
# DESPESAS CORRENTES         20549
# DESPESAS DE CAPITAL         4798
# RESERVA DE CONTINGENCIA       64
# Name: NOME CATEGORIA ECONÔMICA, dtype: int64

# %%
df
# Out:
#        EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR              NOME ÓRGÃO SUPERIOR  \
# 0           2018                   3000      TRIBUNAL DE CONTAS DA UNIAO
# 1           2018                  12000                  JUSTICA FEDERAL
# 2           2018                  20000         PRESIDENCIA DA REPUBLICA
# 3           2018                  20000         PRESIDENCIA DA REPUBLICA
# 4           2018                  20000         PRESIDENCIA DA REPUBLICA
# 5           2018                  20000         PRESIDENCIA DA REPUBLICA
# 6           2018                  20000         PRESIDENCIA DA REPUBLICA
# 7           2018                  20000         PRESIDENCIA DA REPUBLICA
# 8           2018                  20000         PRESIDENCIA DA REPUBLICA
# 9           2018                  20000         PRESIDENCIA DA REPUBLICA
# 10          2018                  20000         PRESIDENCIA DA REPUBLICA
# 11          2018                  20000         PRESIDENCIA DA REPUBLICA
# ...

# %% [markdown]
# # Nomes de despesas

# %%
df['NOME ELEMENTO DE DESPESA'].value_counts()
# Out:
# Não informado                                    4947
# DESPESAS DE EXERCICIOS ANTERIORES                1756
# OUTROS SERVICOS DE TERCEIROS - PESSOA JURIDIC    1515
# INDENIZACOES E RESTITUICOES                      1227
# MATERIAL DE CONSUMO                              1093
# SERVIÇOS DE TECNOLOGIA DA INFORMAÇÃO E COMUNI    1017
# PASSAGENS E DESPESAS COM LOCOMOCAO               1006
# DIARIAS - PESSOAL CIVIL                           955
# OUTROS SERVICOS DE TERCEIROS - PESSOA FISICA      878
# EQUIPAMENTOS E MATERIAL PERMANENTE                847
# SENTENCAS JUDICIAIS                               726
# CONTRIBUICOES                                     717
# OBRAS E INSTALACOES                               568
# OBRIGACOES TRIBUTARIAS E CONTRIBUTIVAS            532
# OUTROS SERVIÇOS DE TERCEIROS - PESSOA JURÍDIC     527
# OBRIG.TRIBUT.E CONTRIB-OP.INTRA-ORCAMENTARIAS     483
# AUXILIO FINANCEIRO A ESTUDANTES                   457
# ...
